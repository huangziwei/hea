# %% [markdown]
# ## Chapter 10 of *R for Data Science* (2e, 2023)

# %%
from hea import data, col

# %% [markdown]
# ### 10.3

# %%
diamonds = data("diamonds")
smaller = diamonds.filter(col("carat") < 3)

# %%
p1 = diamonds.ggplot(x="carat").geom_histogram(binwidth=0.5)
p2 = smaller.ggplot(x="carat").geom_histogram(binwidth=0.01)
p3 = diamonds.ggplot(x="y").geom_histogram(binwidth=0.5)
p4 = diamonds.ggplot(x="y").geom_histogram(binwidth=0.5).coord_cartesian(ylim=[0, 50])

(p1 | p2) / (p3 | p4)
# Out:
# PlotGrid(children=[PlotGrid(children=[ggplot(data=shape: (53_940, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat'), layers=[Layer(geom=GeomBar(default_aes={'colour': None, 'fill': 'grey35', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='polygon'), stat=StatBin(bins=None, binwidth=0.5, boundary=None, center=None, closed='right', pad=False, default_y_label='count'), position=PositionStack(vjust=1.0, reverse=False), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x120c85450>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={}), ggplot(data=shape: (53_900, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat'), layers=[Layer(geom=GeomBar(default_aes={'colour': None, 'fill': 'grey35', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='polygon'), stat=StatBin(bins=None, binwidth=0.01, boundary=None, center=None, closed='right', pad=False, default_y_label='count'), position=PositionStack(vjust=1.0, reverse=False), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x120c8cfc0>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})], direction='h', nrow=None, ncol=None, byrow=True, widths=None, heights=None, annotation=None, guides=None), PlotGrid(children=[ggplot(data=shape: (53_940, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='y'), layers=[Layer(geom=GeomBar(default_aes={'colour': None, 'fill': 'grey35', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='polygon'), stat=StatBin(bins=None, binwidth=0.5, boundary=None, center=None, closed='right', pad=False, default_y_label='count'), position=PositionStack(vjust=1.0, reverse=False), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x120f183b0>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={}), ggplot(data=shape: (53_940, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='y'), layers=[Layer(geom=GeomBar(default_aes={'colour': None, 'fill': 'grey35', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='polygon'), stat=StatBin(bins=None, binwidth=0.5, boundary=None, center=None, closed='right', pad=False, default_y_label='count'), position=PositionStack(vjust=1.0, reverse=False), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x120c76350>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=[0, 50], expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})], direction='h', nrow=None, ncol=None, byrow=True, widths=None, heights=None, annotation=None, guides=None)], direction='v', nrow=None, ncol=None, byrow=True, widths=None, heights=None, annotation=None, guides=None)

# %% [markdown]
# ### 10.5

# %%
from hea.ggplot import after_stat


p1 = diamonds.ggplot(x="price").geom_freqpoly(color="cut", binwidth=500, linewidth=0.75)
p2 = diamonds.ggplot(x="price", y=after_stat("density")).geom_freqpoly(color="cut", binwidth=500, linewidth=0.75)
p1 | p2
# Out:
# PlotGrid(children=[ggplot(data=shape: (53_940, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='price'), layers=[Layer(geom=GeomPath(default_aes={'colour': 'black', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='path', sort_by_x=False, step_direction=None), stat=StatBin(bins=None, binwidth=500, boundary=None, center=None, closed='right', pad=True, default_y_label='count'), position=PositionIdentity(), mapping=None, data=None, aes_params={'color': 'cut', 'linewidth': 0.75}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x120c93860>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={}), ggplot(data=shape: (53_940, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='price', y=after_stat('density')), layers=[Layer(geom=GeomPath(default_aes={'colour': 'black', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='path', sort_by_x=False, step_direction=None), stat=StatBin(bins=None, binwidth=500, boundary=None, center=None, closed='right', pad=True, default_y_label='count'), position=PositionIdentity(), mapping=None, data=None, aes_params={'color': 'cut', 'linewidth': 0.75}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x1358f7590>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})], direction='h', nrow=None, ncol=None, byrow=True, widths=None, heights=None, annotation=None, guides=None)

# %%
diamonds.ggplot(x="cut", y="price").geom_boxplot()
# Out:
# ggplot(data=shape: (53_940, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='cut', y='price'), layers=[Layer(geom=GeomBoxplot(default_aes={'colour': 'grey20', 'fill': 'white', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0, 'shape': 'o'}, required_aes=('x', 'lower', 'middle', 'upper', 'ymin', 'ymax'), key_glyph='polygon', outlier_size=1.5, outlier_colour=None, outlier_alpha=None), stat=StatBoxplot(coef=1.5, width=None), position=PositionDodge(width=None, preserve='total'), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x13638f070>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})

# %%
from hea.ggplot import fct_reorder

mpg = data("mpg", "ggplot2")
mpg.ggplot(x=fct_reorder("class", "hwy", "median"), y="hwy").geom_boxplot()
# Out:
# ggplot(data=shape: (234, 11)
# ┌──────────────┬────────┬───────┬──────┬───┬─────┬─────┬─────┬─────────┐
# │ manufacturer ┆ model  ┆ displ ┆ year ┆ … ┆ cty ┆ hwy ┆ fl  ┆ class   │
# │ ---          ┆ ---    ┆ ---   ┆ ---  ┆   ┆ --- ┆ --- ┆ --- ┆ ---     │
# │ str          ┆ str    ┆ f64   ┆ i64  ┆   ┆ i64 ┆ i64 ┆ str ┆ str     │
# ╞══════════════╪════════╪═══════╪══════╪═══╪═════╪═════╪═════╪═════════╡
# │ audi         ┆ a4     ┆ 1.8   ┆ 1999 ┆ … ┆ 18  ┆ 29  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 1.8   ┆ 1999 ┆ … ┆ 21  ┆ 29  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 2.0   ┆ 2008 ┆ … ┆ 20  ┆ 31  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 2.0   ┆ 2008 ┆ … ┆ 21  ┆ 30  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 2.8   ┆ 1999 ┆ … ┆ 16  ┆ 26  ┆ p   ┆ compact │
# │ …            ┆ …      ┆ …     ┆ …    ┆ … ┆ …   ┆ …   ┆ …   ┆ …       │
# │ volkswagen   ┆ passat ┆ 2.0   ┆ 2008 ┆ … ┆ 19  ┆ 28  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 2.0   ┆ 2008 ┆ … ┆ 21  ┆ 29  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 2.8   ┆ 1999 ┆ … ┆ 16  ┆ 26  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 2.8   ┆ 1999 ┆ … ┆ 18  ┆ 26  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 3.6   ┆ 2008 ┆ … ┆ 17  ┆ 26  ┆ p   ┆ midsize │
# └──────────────┴────────┴───────┴──────┴───┴─────┴─────┴─────┴─────────┘, mapping=aes(x=<function fct_reorder.<locals>.reorder at 0x120cd9d00>, y='hwy'), layers=[Layer(geom=GeomBoxplot(default_aes={'colour': 'grey20', 'fill': 'white', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0, 'shape': 'o'}, required_aes=('x', 'lower', 'middle', 'upper', 'ymin', 'ymax'), key_glyph='polygon', outlier_size=1.5, outlier_colour=None, outlier_alpha=None), stat=StatBoxplot(coef=1.5, width=None), position=PositionDodge(width=None, preserve='total'), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x136446c50>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})

# %%
mpg.ggplot(x="hwy", y=fct_reorder("class", "hwy", "median")).geom_boxplot()
# Out:
# ggplot(data=shape: (234, 11)
# ┌──────────────┬────────┬───────┬──────┬───┬─────┬─────┬─────┬─────────┐
# │ manufacturer ┆ model  ┆ displ ┆ year ┆ … ┆ cty ┆ hwy ┆ fl  ┆ class   │
# │ ---          ┆ ---    ┆ ---   ┆ ---  ┆   ┆ --- ┆ --- ┆ --- ┆ ---     │
# │ str          ┆ str    ┆ f64   ┆ i64  ┆   ┆ i64 ┆ i64 ┆ str ┆ str     │
# ╞══════════════╪════════╪═══════╪══════╪═══╪═════╪═════╪═════╪═════════╡
# │ audi         ┆ a4     ┆ 1.8   ┆ 1999 ┆ … ┆ 18  ┆ 29  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 1.8   ┆ 1999 ┆ … ┆ 21  ┆ 29  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 2.0   ┆ 2008 ┆ … ┆ 20  ┆ 31  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 2.0   ┆ 2008 ┆ … ┆ 21  ┆ 30  ┆ p   ┆ compact │
# │ audi         ┆ a4     ┆ 2.8   ┆ 1999 ┆ … ┆ 16  ┆ 26  ┆ p   ┆ compact │
# │ …            ┆ …      ┆ …     ┆ …    ┆ … ┆ …   ┆ …   ┆ …   ┆ …       │
# │ volkswagen   ┆ passat ┆ 2.0   ┆ 2008 ┆ … ┆ 19  ┆ 28  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 2.0   ┆ 2008 ┆ … ┆ 21  ┆ 29  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 2.8   ┆ 1999 ┆ … ┆ 16  ┆ 26  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 2.8   ┆ 1999 ┆ … ┆ 18  ┆ 26  ┆ p   ┆ midsize │
# │ volkswagen   ┆ passat ┆ 3.6   ┆ 2008 ┆ … ┆ 17  ┆ 26  ┆ p   ┆ midsize │
# └──────────────┴────────┴───────┴──────┴───┴─────┴─────┴─────┴─────────┘, mapping=aes(x='hwy', y=<function fct_reorder.<locals>.reorder at 0x1367d5f80>), layers=[Layer(geom=GeomBoxplot(default_aes={'colour': 'grey20', 'fill': 'white', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0, 'shape': 'o'}, required_aes=('x', 'lower', 'middle', 'upper', 'ymin', 'ymax'), key_glyph='polygon', outlier_size=1.5, outlier_colour=None, outlier_alpha=None), stat=StatBoxplot(coef=1.5, width=None), position=PositionDodge(width=None, preserve='total'), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x1363700b0>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})

# %%
diamonds.ggplot(x="cut", y="color").geom_count()
# Out:
# ggplot(data=shape: (53_940, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='cut', y='color'), layers=[Layer(geom=GeomPoint(default_aes={'colour': 'black', 'size': 1.5, 'shape': 'o', 'alpha': 1.0, 'fill': None, 'stroke': 0.5}, required_aes=('x', 'y'), key_glyph='point'), stat=StatSum(), position=PositionIdentity(), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x10d4d9d10>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})

# %%
diamonds.count("color", "cut").ggplot(x="color", y="cut").geom_tile(fill="n")
# Out:
# ggplot(data=shape: (35, 3)
# ┌───────┬─────────┬──────┐
# │ color ┆ cut     ┆ n    │
# │ ---   ┆ ---     ┆ ---  │
# │ enum  ┆ enum    ┆ u32  │
# ╞═══════╪═════════╪══════╡
# │ E     ┆ Ideal   ┆ 3903 │
# │ E     ┆ Premium ┆ 2337 │
# │ E     ┆ Good    ┆ 933  │
# │ I     ┆ Premium ┆ 1428 │
# │ J     ┆ Good    ┆ 307  │
# │ …     ┆ …       ┆ …    │
# │ G     ┆ Good    ┆ 871  │
# │ G     ┆ Fair    ┆ 314  │
# │ J     ┆ Fair    ┆ 119  │
# │ I     ┆ Fair    ┆ 175  │
# │ D     ┆ Fair    ┆ 163  │
# └───────┴─────────┴──────┘, mapping=aes(x='color', y='cut'), layers=[Layer(geom=GeomTile(default_aes={'colour': None, 'fill': 'grey20', 'size': 0.2, 'linetype': 'solid', 'alpha': 1.0, 'width': 1.0, 'height': 1.0}, required_aes=('x', 'y'), key_glyph='polygon'), stat=StatIdentity(), position=PositionIdentity(), mapping=None, data=None, aes_params={'fill': 'n'}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x136722030>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})

# %%
p1 = smaller.ggplot(x="carat", y="price").geom_point()
p2 = smaller.ggplot(x="carat", y="price").geom_point(alpha=0.01)
p1 | p2
# Out:
# PlotGrid(children=[ggplot(data=shape: (53_900, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat', y='price'), layers=[Layer(geom=GeomPoint(default_aes={'colour': 'black', 'size': 1.5, 'shape': 'o', 'alpha': 1.0, 'fill': None, 'stroke': 0.5}, required_aes=('x', 'y'), key_glyph='point'), stat=StatIdentity(), position=PositionIdentity(), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x13673f660>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={}), ggplot(data=shape: (53_900, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat', y='price'), layers=[Layer(geom=GeomPoint(default_aes={'colour': 'black', 'size': 1.5, 'shape': 'o', 'alpha': 1.0, 'fill': None, 'stroke': 0.5}, required_aes=('x', 'y'), key_glyph='point'), stat=StatIdentity(), position=PositionIdentity(), mapping=None, data=None, aes_params={'alpha': 0.01}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x13687bb60>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})], direction='h', nrow=None, ncol=None, byrow=True, widths=None, heights=None, annotation=None, guides=None)

# %%
p1 = smaller.ggplot(x="carat", y="price").geom_bin2d()
p2 = smaller.ggplot(x="carat", y="price").geom_hex()
p1 | p2
# Out:
# PlotGrid(children=[ggplot(data=shape: (53_900, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat', y='price'), layers=[Layer(geom=GeomTile(default_aes={'colour': None, 'fill': 'grey20', 'size': 0.2, 'linetype': 'solid', 'alpha': 1.0, 'width': 1.0, 'height': 1.0}, required_aes=('x', 'y'), key_glyph='polygon'), stat=StatBin2d(bins=30, binwidth=None, drop=True), position=PositionIdentity(), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x136343cf0>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={}), ggplot(data=shape: (53_900, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat', y='price'), layers=[Layer(geom=GeomHex(default_aes={'colour': None, 'fill': 'grey20', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='polygon'), stat=StatBinhex(bins=30, drop=True), position=PositionIdentity(), mapping=None, data=None, aes_params={}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x136343ca0>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})], direction='h', nrow=None, ncol=None, byrow=True, widths=None, heights=None, annotation=None, guides=None)

# %%
from hea.ggplot import cut_width
p1 = smaller.ggplot(x="carat", y="price").geom_boxplot(group=cut_width("carat", 1))
p2 = smaller.ggplot(x="carat", y="price").geom_boxplot(group=cut_width("carat", 0.1))

p1 + p2
# Out:
# PlotGrid(children=[ggplot(data=shape: (53_900, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat', y='price'), layers=[Layer(geom=GeomBoxplot(default_aes={'colour': 'grey20', 'fill': 'white', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0, 'shape': 'o'}, required_aes=('x', 'lower', 'middle', 'upper', 'ymin', 'ymax'), key_glyph='polygon', outlier_size=1.5, outlier_colour=None, outlier_alpha=None), stat=StatBoxplot(coef=1.5, width=None), position=PositionDodge(width=None, preserve='total'), mapping=None, data=None, aes_params={'group': <function _maybe_lazy.<locals>._lazy at 0x13630dd00>}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x135aa73e0>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={}), ggplot(data=shape: (53_900, 10)
# ┌───────┬───────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ enum      ┆ enum  ┆ enum    ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ … ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# │ …     ┆ …         ┆ …     ┆ …       ┆ … ┆ …     ┆ …    ┆ …    ┆ …    │
# │ 0.72  ┆ Ideal     ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.75 ┆ 5.76 ┆ 3.5  │
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.69 ┆ 5.75 ┆ 3.61 │
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ … ┆ 2757  ┆ 5.66 ┆ 5.68 ┆ 3.56 │
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ … ┆ 2757  ┆ 6.15 ┆ 6.12 ┆ 3.74 │
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ … ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘, mapping=aes(x='carat', y='price'), layers=[Layer(geom=GeomBoxplot(default_aes={'colour': 'grey20', 'fill': 'white', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0, 'shape': 'o'}, required_aes=('x', 'lower', 'middle', 'upper', 'ymin', 'ymax'), key_glyph='polygon', outlier_size=1.5, outlier_colour=None, outlier_alpha=None), stat=StatBoxplot(coef=1.5, width=None), position=PositionDodge(width=None, preserve='total'), mapping=None, data=None, aes_params={'group': <function _maybe_lazy.<locals>._lazy at 0x13630ccc0>}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x135aa6e90>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})], direction='grid', nrow=None, ncol=None, byrow=True, widths=None, heights=None, annotation=None, guides=None)
