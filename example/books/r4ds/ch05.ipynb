# %% [markdown]
# ## Chapter 5 of *R for Data Science* (2e, 2023)

# %% [markdown]
# ### 5.1.1

# %%
from hea import data, col, factor, desc, n

# %% [markdown]
# ### 5.2

# %%
table1 = data("table1", package="tidyr")
table2 = data("table2", package="tidyr")
table3 = data("table3", package="tidyr")

# %%
table1.mutate(rate=col("cases") / col("population") * 10_000)
# Out:
# shape: (6, 5)
# ┌─────────────┬──────┬────────┬────────────┬──────────┐
# │ country     ┆ year ┆ cases  ┆ population ┆ rate     │
# │ ---         ┆ ---  ┆ ---    ┆ ---        ┆ ---      │
# │ str         ┆ i64  ┆ i64    ┆ i64        ┆ f64      │
# ╞═════════════╪══════╪════════╪════════════╪══════════╡
# │ Afghanistan ┆ 1999 ┆ 745    ┆ 19987071   ┆ 0.372741 │
# │ Afghanistan ┆ 2000 ┆ 2666   ┆ 20595360   ┆ 1.294466 │
# │ Brazil      ┆ 1999 ┆ 37737  ┆ 172006362  ┆ 2.19393  │
# │ Brazil      ┆ 2000 ┆ 80488  ┆ 174504898  ┆ 4.612363 │
# │ China       ┆ 1999 ┆ 212258 ┆ 1272915272 ┆ 1.667495 │
# │ China       ┆ 2000 ┆ 213766 ┆ 1280428583 ┆ 1.669488 │
# └─────────────┴──────┴────────┴────────────┴──────────┘

# %%
(
    table1
        .group_by("year")
        .summarize(total_cases=col("cases").sum())
)
# Out:
# shape: (2, 2)
# ┌──────┬─────────────┐
# │ year ┆ total_cases │
# │ ---  ┆ ---         │
# │ i64  ┆ i64         │
# ╞══════╪═════════════╡
# │ 1999 ┆ 250740      │
# │ 2000 ┆ 296920      │
# └──────┴─────────────┘

# %%
(
    table1
        .ggplot(x="year", y="cases")
        .geom_line(group="country", color="grey50")
        .geom_point(color="country", shape="country")
        .scale_x_continuous(breaks=[1999, 2000])
)
# Out:
# ggplot(data=shape: (6, 4)
# ┌─────────────┬──────┬────────┬────────────┐
# │ country     ┆ year ┆ cases  ┆ population │
# │ ---         ┆ ---  ┆ ---    ┆ ---        │
# │ str         ┆ i64  ┆ i64    ┆ i64        │
# ╞═════════════╪══════╪════════╪════════════╡
# │ Afghanistan ┆ 1999 ┆ 745    ┆ 19987071   │
# │ Afghanistan ┆ 2000 ┆ 2666   ┆ 20595360   │
# │ Brazil      ┆ 1999 ┆ 37737  ┆ 172006362  │
# │ Brazil      ┆ 2000 ┆ 80488  ┆ 174504898  │
# │ China       ┆ 1999 ┆ 212258 ┆ 1272915272 │
# │ China       ┆ 2000 ┆ 213766 ┆ 1280428583 │
# └─────────────┴──────┴────────┴────────────┘, mapping=aes(x='year', y='cases'), layers=[Layer(geom=GeomPath(default_aes={'colour': 'black', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='path', sort_by_x=True, step_direction=None), stat=StatIdentity(), position=PositionIdentity(), mapping=None, data=None, aes_params={'group': 'country', 'color': 'grey50'}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False), Layer(geom=GeomPoint(default_aes={'colour': 'black', 'size': 1.5, 'shape': 'o', 'alpha': 1.0, 'fill': None, 'stroke': 0.5}, required_aes=('x', 'y'), key_glyph='point'), stat=StatIdentity(), position=PositionIdentity(), mapping=None, data=None, aes_params={'color': 'country', 'shape': 'country'}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x13141c8c0>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})

# %% [markdown]
# ### 5.3.1

# %%
billboard = data("billboard")
billboard
# Out:
# shape: (317, 79)
# ┌──────────────────┬─────────────────────────┬──────────────┬─────┬───┬──────┬──────┬──────┬──────┐
# │ artist           ┆ track                   ┆ date.entered ┆ wk1 ┆ … ┆ wk73 ┆ wk74 ┆ wk75 ┆ wk76 │
# │ ---              ┆ ---                     ┆ ---          ┆ --- ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ str              ┆ str                     ┆ str          ┆ i64 ┆   ┆ f64  ┆ f64  ┆ f64  ┆ f64  │
# ╞══════════════════╪═════════════════════════╪══════════════╪═════╪═══╪══════╪══════╪══════╪══════╡
# │ 2 Pac            ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 87  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 2Ge+her          ┆ The Hardest Part Of ... ┆ 2000-09-02   ┆ 91  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3 Doors Down     ┆ Kryptonite              ┆ 2000-04-08   ┆ 81  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3 Doors Down     ┆ Loser                   ┆ 2000-10-21   ┆ 76  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 504 Boyz         ┆ Wobble Wobble           ┆ 2000-04-15   ┆ 57  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ …                ┆ …                       ┆ …            ┆ …   ┆ … ┆ …    ┆ …    ┆ …    ┆ …    │
# │ Yankee Grey      ┆ Another Nine Minutes    ┆ 2000-04-29   ┆ 86  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ Yearwood, Trisha ┆ Real Live Woman         ┆ 2000-04-01   ┆ 85  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ Ying Yang Twins  ┆ Whistle While You Tw... ┆ 2000-03-18   ┆ 95  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ Zombie Nation    ┆ Kernkraft 400           ┆ 2000-09-02   ┆ 99  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ matchbox twenty  ┆ Bent                    ┆ 2000-04-29   ┆ 60  ┆ … ┆ null ┆ null ┆ null ┆ null │
# └──────────────────┴─────────────────────────┴──────────────┴─────┴───┴──────┴──────┴──────┴──────┘

# %%
from hea import selectors
billboard.pivot_longer(
    cols=selectors.starts_with("wk"),
    names_to="week",
    values_to="rank",
)
# Out:
# shape: (24_092, 5)
# ┌─────────────────┬─────────────────────────┬──────────────┬──────┬──────┐
# │ artist          ┆ track                   ┆ date.entered ┆ week ┆ rank │
# │ ---             ┆ ---                     ┆ ---          ┆ ---  ┆ ---  │
# │ str             ┆ str                     ┆ str          ┆ str  ┆ f64  │
# ╞═════════════════╪═════════════════════════╪══════════════╪══════╪══════╡
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk1  ┆ 87.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk2  ┆ 82.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk3  ┆ 72.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk4  ┆ 77.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk5  ┆ 87.0 │
# │ …               ┆ …                       ┆ …            ┆ …    ┆ …    │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk72 ┆ null │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk73 ┆ null │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk74 ┆ null │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk75 ┆ null │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk76 ┆ null │
# └─────────────────┴─────────────────────────┴──────────────┴──────┴──────┘

# %%
billboard.pivot_longer(
    cols=selectors.starts_with("wk"),
    names_to="week",
    values_to="rank",
    values_drop_na=True,
)
# Out:
# shape: (5_307, 5)
# ┌─────────────────┬─────────────────────────┬──────────────┬──────┬──────┐
# │ artist          ┆ track                   ┆ date.entered ┆ week ┆ rank │
# │ ---             ┆ ---                     ┆ ---          ┆ ---  ┆ ---  │
# │ str             ┆ str                     ┆ str          ┆ str  ┆ f64  │
# ╞═════════════════╪═════════════════════════╪══════════════╪══════╪══════╡
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk1  ┆ 87.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk2  ┆ 82.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk3  ┆ 72.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk4  ┆ 77.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk5  ┆ 87.0 │
# │ …               ┆ …                       ┆ …            ┆ …    ┆ …    │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk35 ┆ 33.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk36 ┆ 37.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk37 ┆ 38.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk38 ┆ 38.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk39 ┆ 48.0 │
# └─────────────────┴─────────────────────────┴──────────────┴──────┴──────┘

# %%
from hea import Int64
billboard_longer = (
    billboard.pivot_longer(
        cols=selectors.starts_with("wk"),
        names_to="week",
        values_to="rank",
        values_drop_na=True,
        names_prefix="wk",
    ).mutate(
        week=col("week").cast(Int64)
    )
)

# %%
(
    billboard_longer
        .ggplot(x="week", y="rank", group="track")
        .geom_line(alpha=0.25)
        .scale_y_reverse()
)
# Out:
# ggplot(data=shape: (5_307, 5)
# ┌─────────────────┬─────────────────────────┬──────────────┬──────┬──────┐
# │ artist          ┆ track                   ┆ date.entered ┆ week ┆ rank │
# │ ---             ┆ ---                     ┆ ---          ┆ ---  ┆ ---  │
# │ str             ┆ str                     ┆ str          ┆ i64  ┆ f64  │
# ╞═════════════════╪═════════════════════════╪══════════════╪══════╪══════╡
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 1    ┆ 87.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 2    ┆ 82.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 3    ┆ 72.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 4    ┆ 77.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 5    ┆ 87.0 │
# │ …               ┆ …                       ┆ …            ┆ …    ┆ …    │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ 35   ┆ 33.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ 36   ┆ 37.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ 37   ┆ 38.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ 38   ┆ 38.0 │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ 39   ┆ 48.0 │
# └─────────────────┴─────────────────────────┴──────────────┴──────┴──────┘, mapping=aes(x='week', y='rank', group='track'), layers=[Layer(geom=GeomPath(default_aes={'colour': 'black', 'size': 0.5, 'linetype': 'solid', 'alpha': 1.0}, required_aes=('x', 'y'), key_glyph='path', sort_by_x=True, step_direction=None), stat=StatIdentity(), position=PositionIdentity(), mapping=None, data=None, aes_params={'alpha': 0.25}, geom_params={}, stat_params={}, inherit_aes=True, show_legend=True, na_rm=False, broadcast_panels=False)], scales=<hea.ggplot.scales.list.ScalesList object at 0x131432f70>, coordinates=CoordCartesian(is_linear=True, xlim=None, ylim=None, expand=True), facet=FacetNull(scales='fixed'), theme=Theme(elements={'text': element_text(family='', face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.text': element_text(family=None, face=None, colour='grey30', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title': element_text(family=None, face=None, colour='black', size=11, hjust=None, vjust=None, angle=None, lineheight=None), 'axis.title.y': element_text(family=None, face=None, colour=None, size=None, hjust=None, vjust=None, angle=90, lineheight=None), 'axis.ticks': element_line(colour='grey20', size=0.25, linetype=None, lineend=None), 'axis.line': element_blank(), 'plot.title': element_text(family=None, face=None, colour='black', size=13.2, hjust=0, vjust=None, angle=None, lineheight=None), 'plot.background': element_rect(fill='white', colour=None, size=None, linetype=None), 'panel.background': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'panel.border': element_blank(), 'panel.grid': element_line(colour='white', size=None, linetype=None, lineend=None), 'panel.grid.major': element_line(colour='white', size=0.5, linetype=None, lineend=None), 'panel.grid.minor': element_line(colour='white', size=0.25, linetype=None, lineend=None), 'strip.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'strip.background': element_rect(fill='grey85', colour=None, size=None, linetype=None), 'legend.title': element_text(family=None, face=None, colour='black', size=11, hjust=0, vjust=None, angle=None, lineheight=None), 'legend.text': element_text(family=None, face=None, colour='grey10', size=8.8, hjust=None, vjust=None, angle=None, lineheight=None), 'legend.key': element_rect(fill='#EBEBEB', colour=None, size=None, linetype=None), 'legend.background': element_rect(fill='white', colour=None, size=None, linetype=None)}, complete=True), labels={})

# %% [markdown]
# ### 5.3.3

# %%
who2 = data("who2", "tidyr")
who2
# Out:
# shape: (7_240, 58)
# ┌─────────────┬──────┬──────────┬───────────┬───┬────────────┬────────────┬────────────┬──────────┐
# │ country     ┆ year ┆ sp_m_014 ┆ sp_m_1524 ┆ … ┆ rel_f_3544 ┆ rel_f_4554 ┆ rel_f_5564 ┆ rel_f_65 │
# │ ---         ┆ ---  ┆ ---      ┆ ---       ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---      │
# │ str         ┆ i64  ┆ f64      ┆ f64       ┆   ┆ f64        ┆ f64        ┆ f64        ┆ f64      │
# ╞═════════════╪══════╪══════════╪═══════════╪═══╪════════════╪════════════╪════════════╪══════════╡
# │ Afghanistan ┆ 1980 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Afghanistan ┆ 1981 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Afghanistan ┆ 1982 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Afghanistan ┆ 1983 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Afghanistan ┆ 1984 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ …           ┆ …    ┆ …        ┆ …         ┆ … ┆ …          ┆ …          ┆ …          ┆ …        │
# │ Zimbabwe    ┆ 2009 ┆ 125.0    ┆ 578.0     ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Zimbabwe    ┆ 2010 ┆ 150.0    ┆ 710.0     ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Zimbabwe    ┆ 2011 ┆ 152.0    ┆ 784.0     ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Zimbabwe    ┆ 2012 ┆ 120.0    ┆ 783.0     ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Zimbabwe    ┆ 2013 ┆ null     ┆ null      ┆ … ┆ 3526.0     ┆ 1453.0     ┆ 811.0      ┆ 725.0    │
# └─────────────┴──────┴──────────┴───────────┴───┴────────────┴────────────┴────────────┴──────────┘

# %%
(
    who2
        .pivot_longer(
            cols=~who2["country":"year"],
            names_to=["diagnosis", "gender", "age"],
            names_sep="_",
            values_to="count",
        )
)
# Out:
# shape: (405_440, 6)
# ┌─────────────┬──────┬────────┬───────────┬────────┬──────┐
# │ country     ┆ year ┆ count  ┆ diagnosis ┆ gender ┆ age  │
# │ ---         ┆ ---  ┆ ---    ┆ ---       ┆ ---    ┆ ---  │
# │ str         ┆ i64  ┆ f64    ┆ str       ┆ str    ┆ str  │
# ╞═════════════╪══════╪════════╪═══════════╪════════╪══════╡
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 014  │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 1524 │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 2534 │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 3544 │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 4554 │
# │ …           ┆ …    ┆ …      ┆ …         ┆ …      ┆ …    │
# │ Zimbabwe    ┆ 2013 ┆ 4649.0 ┆ rel       ┆ f      ┆ 2534 │
# │ Zimbabwe    ┆ 2013 ┆ 3526.0 ┆ rel       ┆ f      ┆ 3544 │
# │ Zimbabwe    ┆ 2013 ┆ 1453.0 ┆ rel       ┆ f      ┆ 4554 │
# │ Zimbabwe    ┆ 2013 ┆ 811.0  ┆ rel       ┆ f      ┆ 5564 │
# │ Zimbabwe    ┆ 2013 ┆ 725.0  ┆ rel       ┆ f      ┆ 65   │
# └─────────────┴──────┴────────┴───────────┴────────┴──────┘

# %% [markdown]
# ### 5.3.4

# %%
household = data("household", "tidyr")
household
# Out:
# shape: (5, 5)
# ┌────────┬────────────┬────────────┬─────────────┬─────────────┐
# │ family ┆ dob_child1 ┆ dob_child2 ┆ name_child1 ┆ name_child2 │
# │ ---    ┆ ---        ┆ ---        ┆ ---         ┆ ---         │
# │ i64    ┆ str        ┆ str        ┆ str         ┆ str         │
# ╞════════╪════════════╪════════════╪═════════════╪═════════════╡
# │ 1      ┆ 1998-11-26 ┆ 2000-01-29 ┆ Susan       ┆ Jose        │
# │ 2      ┆ 1996-06-22 ┆ null       ┆ Mark        ┆ null        │
# │ 3      ┆ 2002-07-11 ┆ 2004-04-05 ┆ Sam         ┆ Seth        │
# │ 4      ┆ 2004-10-10 ┆ 2009-08-27 ┆ Craig       ┆ Khai        │
# │ 5      ┆ 2000-12-05 ┆ 2005-02-28 ┆ Parker      ┆ Gracie      │
# └────────┴────────────┴────────────┴─────────────┴─────────────┘

# %%
(
    household
        .pivot_longer(
            cols=~household["family"],
            names_to=[".value", "child"],
            names_sep="_",
            values_drop_na=True,
        )
)
# Out:
# shape: (9, 4)
# ┌────────┬────────┬────────────┬────────┐
# │ family ┆ child  ┆ dob        ┆ name   │
# │ ---    ┆ ---    ┆ ---        ┆ ---    │
# │ i64    ┆ str    ┆ str        ┆ str    │
# ╞════════╪════════╪════════════╪════════╡
# │ 1      ┆ child1 ┆ 1998-11-26 ┆ Susan  │
# │ 1      ┆ child2 ┆ 2000-01-29 ┆ Jose   │
# │ 2      ┆ child1 ┆ 1996-06-22 ┆ Mark   │
# │ 3      ┆ child1 ┆ 2002-07-11 ┆ Sam    │
# │ 3      ┆ child2 ┆ 2004-04-05 ┆ Seth   │
# │ 4      ┆ child1 ┆ 2004-10-10 ┆ Craig  │
# │ 4      ┆ child2 ┆ 2009-08-27 ┆ Khai   │
# │ 5      ┆ child1 ┆ 2000-12-05 ┆ Parker │
# │ 5      ┆ child2 ┆ 2005-02-28 ┆ Gracie │
# └────────┴────────┴────────────┴────────┘

# %% [markdown]
# ### 5.4

# %%
exp = data("cms_patient_experience", "tidyr")
exp
# Out:
# shape: (500, 5)
# ┌────────────┬─────────────────────────────┬──────────────┬─────────────────────────────┬──────────┐
# │ org_pac_id ┆ org_nm                      ┆ measure_cd   ┆ measure_title               ┆ prf_rate │
# │ ---        ┆ ---                         ┆ ---          ┆ ---                         ┆ ---      │
# │ i64        ┆ str                         ┆ str          ┆ str                         ┆ f64      │
# ╞════════════╪═════════════════════════════╪══════════════╪═════════════════════════════╪══════════╡
# │ 446157747  ┆ USC CARE MEDICAL GROUP INC  ┆ CAHPS_GRP_1  ┆ CAHPS for MIPS SSM: Getting ┆ 63.0     │
# │            ┆                             ┆              ┆ Ti…                         ┆          │
# │ 446157747  ┆ USC CARE MEDICAL GROUP INC  ┆ CAHPS_GRP_2  ┆ CAHPS for MIPS SSM: How     ┆ 87.0     │
# │            ┆                             ┆              ┆ Well P…                     ┆          │
# │ 446157747  ┆ USC CARE MEDICAL GROUP INC  ┆ CAHPS_GRP_3  ┆ CAHPS for MIPS SSM:         ┆ 86.0     │
# │            ┆                             ┆              ┆ Patient's …                 ┆          │
# │ 446157747  ┆ USC CARE MEDICAL GROUP INC  ┆ CAHPS_GRP_5  ┆ CAHPS for MIPS SSM: Health  ┆ 57.0     │
# │            ┆                             ┆              ┆ Pro…                        ┆          │
# │ 446157747  ┆ USC CARE MEDICAL GROUP INC  ┆ CAHPS_GRP_8  ┆ CAHPS for MIPS SSM:         ┆ 85.0     │
# │            ┆                             ┆              ┆ Courteous …                 ┆          │
# │ …          ┆ …                           ┆ …            ┆ …                           ┆ …        │
# │ 9931011434 ┆ PATIENT FIRST RICHMOND      ┆ CAHPS_GRP_1  ┆ CAHPS for MIPS SSM: Getting ┆ 80.0     │
# │            ┆ MEDICAL…                    ┆              ┆ Ti…                         ┆          │
# │ 9931011434 ┆ PATIENT FIRST RICHMOND      ┆ CAHPS_GRP_2  ┆ CAHPS for MIPS SSM: How     ┆ null     │
# │            ┆ MEDICAL…                    ┆              ┆ Well P…                     ┆          │
# │ 9931011434 ┆ PATIENT FIRST RICHMOND      ┆ CAHPS_GRP_3  ┆ CAHPS for MIPS SSM:         ┆ null     │
# │            ┆ MEDICAL…                    ┆              ┆ Patient's …                 ┆          │
# │ 9931011434 ┆ PATIENT FIRST RICHMOND      ┆ CAHPS_GRP_5  ┆ CAHPS for MIPS SSM: Health  ┆ 45.0     │
# │            ┆ MEDICAL…                    ┆              ┆ Pro…                        ┆          │
# │ 9931011434 ┆ PATIENT FIRST RICHMOND      ┆ CAHPS_GRP_12 ┆ CAHPS for MIPS SSM:         ┆ 19.0     │
# │            ┆ MEDICAL…                    ┆              ┆ Stewardshi…                 ┆          │
# └────────────┴─────────────────────────────┴──────────────┴─────────────────────────────┴──────────┘

# %%
(
    exp
        .distinct("measure_cd", "measure_title")
)
# Out:
# shape: (6, 2)
# ┌──────────────┬─────────────────────────────────┐
# │ measure_cd   ┆ measure_title                   │
# │ ---          ┆ ---                             │
# │ str          ┆ str                             │
# ╞══════════════╪═════════════════════════════════╡
# │ CAHPS_GRP_1  ┆ CAHPS for MIPS SSM: Getting Ti… │
# │ CAHPS_GRP_2  ┆ CAHPS for MIPS SSM: How Well P… │
# │ CAHPS_GRP_3  ┆ CAHPS for MIPS SSM: Patient's … │
# │ CAHPS_GRP_5  ┆ CAHPS for MIPS SSM: Health Pro… │
# │ CAHPS_GRP_8  ┆ CAHPS for MIPS SSM: Courteous … │
# │ CAHPS_GRP_12 ┆ CAHPS for MIPS SSM: Stewardshi… │
# └──────────────┴─────────────────────────────────┘

# %%
(
    exp.
        pivot_wider(
            names_from="measure_cd",
            values_from="prf_rate"
        )
)
# Out:
# shape: (500, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ org_pac_i ┆ org_nm    ┆ measure_t ┆ CAHPS_GRP ┆ … ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GR │
# │ d         ┆ ---       ┆ itle      ┆ _1        ┆   ┆ _3        ┆ _5        ┆ _8        ┆ P_12     │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆           ┆ str       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 446157747 ┆ USC CARE  ┆ CAHPS for ┆ 63.0      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ MEDICAL   ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ GROUP INC ┆ Getting   ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Ti…       ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 446157747 ┆ USC CARE  ┆ CAHPS for ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ MEDICAL   ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ GROUP INC ┆ How Well  ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ P…        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 446157747 ┆ USC CARE  ┆ CAHPS for ┆ null      ┆ … ┆ 86.0      ┆ null      ┆ null      ┆ null     │
# │           ┆ MEDICAL   ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ GROUP INC ┆ Patient's ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ …         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 446157747 ┆ USC CARE  ┆ CAHPS for ┆ null      ┆ … ┆ null      ┆ 57.0      ┆ null      ┆ null     │
# │           ┆ MEDICAL   ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ GROUP INC ┆ Health    ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Pro…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 446157747 ┆ USC CARE  ┆ CAHPS for ┆ null      ┆ … ┆ null      ┆ null      ┆ 85.0      ┆ null     │
# │           ┆ MEDICAL   ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ GROUP INC ┆ Courteous ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ …         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 993101143 ┆ PATIENT   ┆ CAHPS for ┆ 80.0      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 4         ┆ FIRST     ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ RICHMOND  ┆ Getting   ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ MEDICAL…  ┆ Ti…       ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 993101143 ┆ PATIENT   ┆ CAHPS for ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 4         ┆ FIRST     ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ RICHMOND  ┆ How Well  ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ MEDICAL…  ┆ P…        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 993101143 ┆ PATIENT   ┆ CAHPS for ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 4         ┆ FIRST     ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ RICHMOND  ┆ Patient's ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ MEDICAL…  ┆ …         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 993101143 ┆ PATIENT   ┆ CAHPS for ┆ null      ┆ … ┆ null      ┆ 45.0      ┆ null      ┆ null     │
# │ 4         ┆ FIRST     ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ RICHMOND  ┆ Health    ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ MEDICAL…  ┆ Pro…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 993101143 ┆ PATIENT   ┆ CAHPS for ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ 19.0     │
# │ 4         ┆ FIRST     ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ RICHMOND  ┆ Stewardsh ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ MEDICAL…  ┆ i…        ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
(
    exp.
        pivot_wider(
            id_cols=selectors.starts_with("org"),
            names_from="measure_cd",
            values_from="prf_rate"
        )
)
# Out:
# shape: (95, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ org_pac_id ┆ org_nm     ┆ CAHPS_GRP_ ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP │
# │ ---        ┆ ---        ┆ 1          ┆ _2        ┆ _3        ┆ _5        ┆ _8        ┆ _12       │
# │ i64        ┆ str        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆ f64        ┆ f64       ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 446157747  ┆ USC CARE   ┆ 63.0       ┆ 87.0      ┆ 86.0      ┆ 57.0      ┆ 85.0      ┆ 24.0      │
# │            ┆ MEDICAL    ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ GROUP INC  ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 446162697  ┆ ASSOCIATIO ┆ 59.0       ┆ 85.0      ┆ 83.0      ┆ 63.0      ┆ 88.0      ┆ 22.0      │
# │            ┆ N OF       ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ UNIVERSITY ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ PHYS…      ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 547164295  ┆ BEAVER     ┆ 49.0       ┆ null      ┆ 75.0      ┆ 44.0      ┆ 73.0      ┆ 12.0      │
# │            ┆ MEDICAL    ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ GROUP PC   ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 749333730  ┆ CAPE       ┆ 67.0       ┆ 84.0      ┆ 85.0      ┆ 65.0      ┆ 82.0      ┆ 24.0      │
# │            ┆ PHYSICIANS ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ ASSOCIATES ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ PA         ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 840104360  ┆ ALLIANCE   ┆ 66.0       ┆ 87.0      ┆ 87.0      ┆ 64.0      ┆ 87.0      ┆ 28.0      │
# │            ┆ PHYSICIANS ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ INC        ┆            ┆           ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 9830002617 ┆ VIRGINIA   ┆ 55.0       ┆ 81.0      ┆ 80.0      ┆ 62.0      ┆ null      ┆ 20.0      │
# │            ┆ MASON      ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ MEDICAL    ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ CENTER     ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 9830008770 ┆ WASHINGTON ┆ 65.0       ┆ null      ┆ null      ┆ 61.0      ┆ null      ┆ 28.0      │
# │            ┆ UNIVERSITY ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 9830093640 ┆ COOPERATIV ┆ 65.0       ┆ 87.0      ┆ 78.0      ┆ 52.0      ┆ null      ┆ 25.0      │
# │            ┆ E          ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ HEALTHCARE ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ SERVICE…   ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 9830094515 ┆ SUTTER     ┆ 60.0       ┆ null      ┆ 88.0      ┆ 55.0      ┆ null      ┆ 24.0      │
# │            ┆ VALLEY     ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ MEDICAL    ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ FOUNDATI…  ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 9931011434 ┆ PATIENT    ┆ 80.0       ┆ null      ┆ null      ┆ 45.0      ┆ null      ┆ 19.0      │
# │            ┆ FIRST      ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ RICHMOND   ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ MEDICAL…   ┆            ┆           ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘
